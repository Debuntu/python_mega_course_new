# %%
df = pandas.read_csv("topics.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 df = pandas.read_csv("topics.csv")
#
# NameError: name 'pandas' is not defined

# %%
import pandas
df = pandas.read_csv("topics.csv")

# %%
print(df)
# Out:
#                topic
# 0      Job Inquiries
# 1  Project Proposals
# 2              Other

# %%
import streamlit as st
for index, row in df[0:].iterrows():
    st.header(row["topic"])
# Out:
# 2025-01-22 23:58:04.626
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/ipykernel_launcher.py [ARGUMENTS]

# %%
l = df.topic.to
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 l = df.topic.totuple()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'totuple'

# %%
print(l)
# Out:
# ['Job Inquiries', 'Project Proposals', 'Other']
